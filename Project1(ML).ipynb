# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
DF=pd.read_csv("train.csv")
DF
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
DF.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                  Name   Sex  \
# count    891.000000  891.000000  891.000000                   891   891
# unique          NaN         NaN         NaN                   891     2
# top             NaN         NaN         NaN  Youseff, Mr. Gerious  male
# freq            NaN         NaN         NaN                     1   577
# mean     446.000000    0.383838    2.308642                   NaN   NaN
# std      257.353842    0.486592    0.836071                   NaN   NaN
# min        1.000000    0.000000    1.000000                   NaN   NaN
# 25%      223.500000    0.000000    2.000000                   NaN   NaN
# 50%      446.000000    0.000000    3.000000                   NaN   NaN
# 75%      668.500000    1.000000    3.000000                   NaN   NaN
# max      891.000000    1.000000    3.000000                   NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare        Cabin  \
# count   714.000000  891.000000  891.000000       891  891.000000          204
# unique         NaN         NaN         NaN       681         NaN          147
# top            NaN         NaN         NaN  CA. 2343         NaN  C23 C25 C27
# freq           NaN         NaN         NaN         7         NaN            4
# mean     29.699118    0.523008    0.381594       NaN   32.204208          NaN
# std      14.526497    1.102743    0.806057       NaN   49.693429          NaN
# min       0.420000    0.000000    0.000000       NaN    0.000000          NaN
# 25%      20.125000    0.000000    0.000000       NaN    7.910400          NaN
# 50%      28.000000    0.000000    0.000000       NaN   14.454200          NaN
# 75%      38.000000    1.000000    0.000000       NaN   31.000000          NaN
# max      80.000000    8.000000    6.000000       NaN  512.329200          NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
DF
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
fig=plt.figure(figsize=(12,5))
sns.heatmap(DF.isnull())

# %%
sns.barplot(DF['Pclass'],DF['Age'])

# %%
sns.countplot('Pclass',hue='Sex',data=DF)

# %%
sns.barplot(DF['Pclass'],DF['Age'],hue=DF['Sex'],estimator=np.std)

# %%
DF.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.309955    0.523008
# std     257.353842    0.486592    0.836071   13.300377    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   26.000000    0.000000
# 75%     668.500000    1.000000    3.000000   36.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
DF.loc[19,'Age']=32

# %%
for i in range(0,891):
    if pd.isnull(DF['Age'][i]):
        if DF['Pclass'][i]==1:
            if DF['Sex'][i]=='male':
                DF.loc[i,'Age']=42
            else:
                DF.loc[i,'Age']=34
        elif DF['Pclass'][i]==2:
            if DF['Sex'][i]=='male':
                DF.loc[i,'Age']=32
            else:
                DF.loc[i,'Age']=28
        if DF['Pclass'][i]==3:
            if DF['Sex'][i]=='male':
                DF.loc[i,'Age']=26
            else:
                DF.loc[i,'Age']=22
    else:
        continue

# %%
DF.describe()

# %%
sns.heatmap(DF.isnull())

# %%
DF=DF.drop('Cabin',axis=1)
DF=DF.drop('Ticket',axis=1)
DF=DF.drop('Name',axis=1)
DF=DF.drop('PassengerId',axis=1)

# %%
DF.describe()
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(DF[['Fare','Age']])
DF[['Fare','Age']]=scaler.transform(DF[['Fare','Age']])

# %%
DF['Age']

# %%
DF
# Out:
#      Survived  Pclass     Sex       Age  SibSp  Parch      Fare Embarked
# 0           0       3    male -0.549914      1      0 -0.502445        S
# 1           1       1  female  0.653735      1      0  0.786845        C
# 2           1       3  female -0.249002      0      0 -0.488854        S
# 3           1       1  female  0.428051      1      0  0.420730        S
# 4           0       3    male  0.428051      0      0 -0.486337        S
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 886         0       2    male -0.173773      0      0 -0.386671        S
# 887         1       1  female -0.775598      0      0 -0.044381        S
# 888         0       3  female -0.549914      1      2 -0.176263        S
# 889         1       1    male -0.249002      0      0 -0.044381        C
# 890         0       3    male  0.202367      0      0 -0.492378        Q
#
# [891 rows x 8 columns]

# %%
# Out:
#      Survived  Pclass     Sex       Age  SibSp  Parch      Fare Embarked
# 0           0       3    male -0.549914      1      0 -0.502445        S
# 1           1       1  female  0.653735      1      0  0.786845        C
# 2           1       3  female -0.249002      0      0 -0.488854        S
# 3           1       1  female  0.428051      1      0  0.420730        S
# 4           0       3    male  0.428051      0      0 -0.486337        S
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 886         0       2    male -0.173773      0      0 -0.386671        S
# 887         1       1  female -0.775598      0      0 -0.044381        S
# 888         0       3  female -0.549914      1      2 -0.176263        S
# 889         1       1    male -0.249002      0      0 -0.044381        C
# 890         0       3    male  0.202367      0      0 -0.492378        Q
#
# [890 rows x 8 columns]

# %%
DF1=pd.get_dummies(DF,drop_first=True)
DF1=DF1.drop('SibSp',axis=1)
DF1=DF1.drop('Parch',axis=1)

# %%
Drop=[]
for i in range(0,891):
    if DF1['Age'][i]>3:
        Drop.append(i)
        DF1=DF1.drop([i])
    else:
        continue
Drop
# Out:
# [96, 116, 493, 630, 672, 745, 851]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-277-0ed186cb18a4> in <module>
# ----> 1 DF1=DF1.reset_index()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4602                 # to ndarray and maybe infer different dtype
#    4603                 level_values = _maybe_casted_values(lev, lab)
# -> 4604                 new_obj.insert(0, name, level_values)
#    4605
#    4606         new_obj.index = new_index
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
#    3495         value = self._sanitize_column(column, value, broadcast=False)
# -> 3496         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3497
#    3498     def assign(self, **kwargs) -> "DataFrame":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# -> 1173             raise ValueError(f"cannot insert {item}, already exists")
#    1174
#    1175         if not isinstance(loc, int):
#
# ValueError: cannot insert level_0, already exists

# %%
Drop=[]
for i in range(864):
    if DF1['Fare'][i]>3:
        Drop.append(i)
        DF1=DF1.drop([i])
    else:
        continue

# %%
DF1[DF1['Fare']>3]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, Fare, Sex_male, Embarked_Q, Embarked_S]
# Index: []

# %%
X=DF1[['Pclass', 'Age', 'Fare', 'Sex_male',
       'Embarked_Q', 'Embarked_S']]
y=DF1['Survived']

# %%
DF1[DF1['Fare']>3].count()
# Out:
# Survived      0
# Pclass        0
# Age           0
# Fare          0
# Sex_male      0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=101)

# %%
from sklearn.neighbors import KNeighborsClassifier
Error=[]
for i in range(1,40):
    KNN=KNeighborsClassifier(n_neighbors=i)
    KNN.fit(X_train,y_train)
    pred=KNN.predict(X_test)
    Error.append(np.mean(pred!=y_test))

# %%
plt.figure(figsize=(15,3))
plt.plot(range(1,40),Error,marker='o')

# %%
KNN=KNeighborsClassifier(n_neighbors=8)
KNN.fit(X_train,y_train)
pred=KNN.predict(X_test)
pred
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[206  22]
#  [ 32  86]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88       228
#            1       0.80      0.73      0.76       118
#
#     accuracy                           0.84       346
#    macro avg       0.83      0.82      0.82       346
# weighted avg       0.84      0.84      0.84       346

# %%
DF1
# Out:
#      Survived  Pclass       Age      Fare  Sex_male  Embarked_Q  Embarked_S
# 0           0       3 -0.549914 -0.502445         1           0           1
# 1           1       1  0.653735  0.786845         0           0           0
# 2           1       3 -0.249002 -0.488854         0           0           1
# 3           1       1  0.428051  0.420730         0           0           1
# 4           0       3  0.428051 -0.486337         1           0           1
# ..        ...     ...       ...       ...       ...         ...         ...
# 859         0       2 -0.173773 -0.386671         1           0           1
# 860         1       1 -0.775598 -0.044381         0           0           1
# 861         0       3 -0.549914 -0.176263         0           0           1
# 862         1       1 -0.249002 -0.044381         1           0           0
# 863         0       3  0.202367 -0.492378         1           1           0
#
# [864 rows x 7 columns]

# %%
DF1=DF1.reset_index(drop=True)
DF1
# Out:
#      Survived  Pclass       Age      Fare  Sex_male  Embarked_Q  Embarked_S
# 0           0       3 -0.549914 -0.502445         1           0           1
# 1           1       1  0.653735  0.786845         0           0           0
# 2           1       3 -0.249002 -0.488854         0           0           1
# 3           1       1  0.428051  0.420730         0           0           1
# 4           0       3  0.428051 -0.486337         1           0           1
# ..        ...     ...       ...       ...       ...         ...         ...
# 859         0       2 -0.173773 -0.386671         1           0           1
# 860         1       1 -0.775598 -0.044381         0           0           1
# 861         0       3 -0.549914 -0.176263         0           0           1
# 862         1       1 -0.249002 -0.044381         1           0           0
# 863         0       3  0.202367 -0.492378         1           1           0
#
# [864 rows x 7 columns]
